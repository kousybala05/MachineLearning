# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('Automobile.csv')
df
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...

# %%
df.groupby(['fuel_type']).size()
# Out:
# fuel_type
# diesel     20
# gas       181
# dtype: int64

# %%
df.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
df.head(10)
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
# 5          2                161         audi       gas        std
# 6          1                158         audi       gas        std
# 7          1                168         audi       gas        std
# 8          1                158         audi       gas      turbo
# 9          2                192          bmw       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# ...

# %%
df.tail()
# Out:
#      symboling  normalized_losses   make fuel_type aspiration number_of_doors  \
# 196         -1                 95  volvo       gas        std            four
# 197         -1                 95  volvo       gas      turbo            four
# 198         -1                 95  volvo       gas        std            four
# 199         -1                 95  volvo    diesel      turbo            four
# 200         -1                 95  volvo       gas      turbo            four
#
#     body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# 196      sedan          rwd           front       109.1  ...          141
# 197      sedan          rwd           front       109.1  ...          141
# 198      sedan          rwd           front       109.1  ...          173
# 199      sedan          rwd           front       109.1  ...          145
# 200      sedan          rwd           front       109.1  ...          141
#
# ...

# %%
df.tail(10)
# Out:
#      symboling  normalized_losses   make fuel_type aspiration number_of_doors  \
# 191         -1                 74  volvo       gas        std            four
# 192         -2                103  volvo       gas        std            four
# 193         -1                 74  volvo       gas        std            four
# 194         -2                103  volvo       gas      turbo            four
# 195         -1                 74  volvo       gas      turbo            four
# 196         -1                 95  volvo       gas        std            four
# 197         -1                 95  volvo       gas      turbo            four
# 198         -1                 95  volvo       gas        std            four
# 199         -1                 95  volvo    diesel      turbo            four
# 200         -1                 95  volvo       gas      turbo            four
#
#     body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# ...

# %%
df.dtypes
# Out:
# symboling                int64
# normalized_losses        int64
# make                    object
# fuel_type               object
# aspiration              object
# number_of_doors         object
# body_style              object
# drive_wheels            object
# engine_location         object
# wheel_base             float64
# length                 float64
# width                  float64
# height                 float64
# curb_weight              int64
# engine_type             object
# number_of_cylinders     object
# engine_size              int64
# fuel_system             object
# bore                   float64
# stroke                 float64
# compression_ratio      float64
# horsepower               int64
# peak_rpm                 int64
# city_mpg                 int64
# highway_mpg              int64
# price                    int64
# dtype: object

# %%
df.sample()
# Out:
#      symboling  normalized_losses     make fuel_type aspiration  \
# 123          3                128  porsche       gas        std
#
#     number_of_doors body_style drive_wheels engine_location  wheel_base  ...  \
# 123             two    hardtop          rwd            rear        89.5  ...
#
#      engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# 123          194         mpfi  3.74     2.9               9.5        207
#
#      peak_rpm city_mpg  highway_mpg  price
# 123      5900       17           25  32528
#
# [1 rows x 26 columns]

# %%
df.sample(5)
# Out:
#      symboling  normalized_losses     make fuel_type aspiration  \
# 127          2                129  renault       gas        std
# 34           0                110    honda       gas        std
# 128          3                150     saab       gas        std
# 194         -2                103    volvo       gas      turbo
# 6            1                158     audi       gas        std
#
#     number_of_doors body_style drive_wheels engine_location  wheel_base  ...  \
# 127             two  hatchback          fwd           front        96.1  ...
# 34             four      sedan          fwd           front        96.5  ...
# 128             two  hatchback          fwd           front        99.1  ...
# 194            four      sedan          rwd           front       104.3  ...
# 6              four      sedan          fwd           front       105.8  ...
#
#      engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
df.shape
# Out:
# (201, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   symboling            201 non-null    int64
#  1   normalized_losses    201 non-null    int64
#  2   make                 201 non-null    object
#  3   fuel_type            201 non-null    object
#  4   aspiration           201 non-null    object
#  5   number_of_doors      201 non-null    object
#  6   body_style           201 non-null    object
#  7   drive_wheels         201 non-null    object
#  8   engine_location      201 non-null    object
#  9   wheel_base           201 non-null    float64
#  10  length               201 non-null    float64
#  11  width                201 non-null    float64
#  12  height               201 non-null    float64
#  13  curb_weight          201 non-null    int64
#  14  engine_type          201 non-null    object
# ...

# %%
df.iloc[10]
# Out:
# symboling                  0
# normalized_losses        192
# make                     bmw
# fuel_type                gas
# aspiration               std
# number_of_doors         four
# body_style             sedan
# drive_wheels             rwd
# engine_location        front
# wheel_base             101.2
# length                 176.8
# width                   64.8
# height                  54.3
# curb_weight             2395
# engine_type              ohc
# number_of_cylinders     four
# engine_size              108
# fuel_system             mpfi
# bore                     3.5
# stroke                   2.8
# compression_ratio        8.8
# horsepower               101
# peak_rpm                5800
# city_mpg                  23
# highway_mpg               29
# price                  16925
# Name: 10, dtype: object

# %%
df.iloc[2]['bore']
# Out:
# 2.68

# %%
df.iloc[2:8]
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
# 5          2                161         audi       gas        std
# 6          1                158         audi       gas        std
# 7          1                168         audi       gas        std
#
#   number_of_doors body_style drive_wheels engine_location  wheel_base  ...  \
# 2             two  hatchback          rwd           front        94.5  ...
# 3            four      sedan          fwd           front        99.8  ...
# 4            four      sedan          4wd           front        99.4  ...
# 5             two      sedan          fwd           front        99.8  ...
# 6            four      sedan          fwd           front       105.8  ...
# ...

# %%
df.iloc[:,:2]
# Out:
#      symboling  normalized_losses
# 0            3                168
# 1            3                168
# 2            1                168
# 3            2                164
# 4            2                164
# ..         ...                ...
# 196         -1                 95
# 197         -1                 95
# 198         -1                 95
# 199         -1                 95
# 200         -1                 95
#
# [201 rows x 2 columns]

# %%
df.loc[5]
# Out:
# symboling                  2
# normalized_losses        161
# make                    audi
# fuel_type                gas
# aspiration               std
# number_of_doors          two
# body_style             sedan
# drive_wheels             fwd
# engine_location        front
# wheel_base              99.8
# length                 177.3
# width                   66.3
# height                  53.1
# curb_weight             2507
# engine_type              ohc
# number_of_cylinders     five
# engine_size              136
# fuel_system             mpfi
# bore                    3.19
# stroke                   3.4
# compression_ratio        8.5
# horsepower               110
# peak_rpm                5500
# city_mpg                  19
# highway_mpg               25
# price                  15250
# Name: 5, dtype: object

# %%
df.loc[3]['bore']
# Out:
# 3.19

# %%
df.loc[[0,1,2],['stroke','price']]
# Out:
#    stroke  price
# 0    2.68  13495
# 1    2.68  16500
# 2    3.47  16500

# %%
df[df.price>20000]
# Out:
#      symboling  normalized_losses           make fuel_type aspiration  \
# 8            1                158           audi       gas      turbo
# 11           0                188            bmw       gas        std
# 12           0                188            bmw       gas        std
# 13           1                149            bmw       gas        std
# 14           0                149            bmw       gas        std
# 15           0                149            bmw       gas        std
# 16           0                149            bmw       gas        std
# 44           0                145         jaguar       gas        std
# 45           0                115         jaguar       gas        std
# 46           0                115         jaguar       gas        std
# 64          -1                 93  mercedes-benz    diesel      turbo
# 65          -1                 93  mercedes-benz    diesel      turbo
# ...

# %%
df[(df.normalized_losses>150)&(df.fuel_type=='gas')]
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# 5            2                161         audi       gas        std
# 6            1                158         audi       gas        std
# 7            1                168         audi       gas        std
# 8            1                158         audi       gas      turbo
# 9            2                192          bmw       gas        std
# 10           0                192          bmw       gas        std
# 11           0                188          bmw       gas        std
# 12           0                188          bmw       gas        std
# ...

# %%
df[(df.fuel_type=='gas')&(df.make=='bmw')]
# Out:
#     symboling  normalized_losses make fuel_type aspiration number_of_doors  \
# 9           2                192  bmw       gas        std             two
# 10          0                192  bmw       gas        std            four
# 11          0                188  bmw       gas        std             two
# 12          0                188  bmw       gas        std            four
# 13          1                149  bmw       gas        std            four
# 14          0                149  bmw       gas        std            four
# 15          0                149  bmw       gas        std             two
# 16          0                149  bmw       gas        std            four
#
#    body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# 9       sedan          rwd           front       101.2  ...          108
# 10      sedan          rwd           front       101.2  ...          108
# ...

# %%
df.sort_values('price')
# Out:
#      symboling  normalized_losses           make fuel_type aspiration  \
# 134          2                 83         subaru       gas        std
# 17           2                121      chevrolet       gas        std
# 47           1                104          mazda       gas        std
# 146          1                 87         toyota       gas        std
# 73           2                161     mitsubishi       gas        std
# ..         ...                ...            ...       ...        ...
# 16           0                149            bmw       gas        std
# 125          3                128        porsche       gas        std
# 70           0                140  mercedes-benz       gas        std
# 15           0                149            bmw       gas        std
# 71           1                140  mercedes-benz       gas        std
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# ...

# %%
df.sort_values('number_of_doors',ascending='False')
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 100          0                108       nissan       gas        std
# 113          0                161       peugot    diesel      turbo
# 114          0                161       peugot       gas      turbo
# 117          1                154     plymouth       gas        std
# 118          1                154     plymouth       gas        std
# ..         ...                ...          ...       ...        ...
# 49           1                104        mazda       gas        std
# 52           3                150        mazda       gas        std
# 116          1                119     plymouth       gas      turbo
# 147          1                 87       toyota       gas        std
# 0            3                168  alfa-romero       gas        std
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 100            four        sedan          fwd           front       100.4
# ...

# %%
df.sort_values(['number_of_doors','symboling'])
# Out:
#      symboling  normalized_losses           make fuel_type aspiration  \
# 190         -2                103          volvo       gas        std
# 192         -2                103          volvo       gas        std
# 194         -2                103          volvo       gas      turbo
# 27          -1                110          dodge       gas        std
# 64          -1                 93  mercedes-benz    diesel      turbo
# ..         ...                ...            ...       ...        ...
# 132          3                150           saab       gas      turbo
# 174          3                197         toyota       gas        std
# 175          3                197         toyota       gas        std
# 185          3                137     volkswagen       gas        std
# 186          3                256     volkswagen       gas        std
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# ...

# %%
df[df.make=='volvo'].sort_index(ascending=False)
# Out:
#      symboling  normalized_losses   make fuel_type aspiration number_of_doors  \
# 200         -1                 95  volvo       gas      turbo            four
# 199         -1                 95  volvo    diesel      turbo            four
# 198         -1                 95  volvo       gas        std            four
# 197         -1                 95  volvo       gas      turbo            four
# 196         -1                 95  volvo       gas        std            four
# 195         -1                 74  volvo       gas      turbo            four
# 194         -2                103  volvo       gas      turbo            four
# 193         -1                 74  volvo       gas        std            four
# 192         -2                103  volvo       gas        std            four
# 191         -1                 74  volvo       gas        std            four
# 190         -2                103  volvo       gas        std            four
#
# ...

# %%
df['newrank']=df.engine_size.rank(method='min')

# %%
df.newrank
# Out:
# 0      129.0
# 1      129.0
# 2      160.0
# 3       79.0
# 4      138.0
#        ...
# 196    145.0
# 197    145.0
# 198    178.0
# 199    152.0
# 200    145.0
# Name: newrank, Length: 201, dtype: float64

# %%
df
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...

# %%
df['new_rank']=df.engine_size.rank(method='max')

# %%
df
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...

# %%
df['new_rank']=df.wheel_base.rank()
df
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...

# %%
data={'name':['A','B','C','D','E'],'salary':[23333,45555,6777,445,34452],'gender':['F','M','M','F','M'],'age':[23,4,52,24,25]}
df1=pd.DataFrame(data)
df1
# Out:
#   name  salary gender  age
# 0    A   23333      F   23
# 1    B   45555      M    4
# 2    C    6777      M   52
# 3    D     445      F   24
# 4    E   34452      M   25

# %%
#melt
df_melt=df1.melt(id_vars=['gender'])

# %%
df_melt
# Out:
#    gender variable  value
# 0       F     name      A
# 1       M     name      B
# 2       M     name      C
# 3       F     name      D
# 4       M     name      E
# 5       F   salary  23333
# 6       M   salary  45555
# 7       M   salary   6777
# 8       F   salary    445
# 9       M   salary  34452
# 10      F      age     23
# 11      M      age      4
# 12      M      age     52
# 13      F      age     24
# 14      M      age     25

# %%
df1_melt=df1.melt(id_vars=['gender'] ,value_vars=['name'])

# %%
df1_melt
# Out:
#   gender variable value
# 0      F     name     A
# 1      M     name     B
# 2      M     name     C
# 3      F     name     D
# 4      M     name     E

# %%
df1
# Out:
#   name  salary gender  age
# 0    A   23333      F   23
# 1    B   45555      M    4
# 2    C    6777      M   52
# 3    D     445      F   24
# 4    E   34452      M   25

# %%
pd.pivot_table(df1,index=['gender'],values=['age'])
# Out:
#          age
# gender
# F       23.5
# M       27.0

# %%
pd.pivot_table(df1 , index=['name'] , values=['salary'] , aggfunc='sum')
# Out:
#       salary
# name
# A      23333
# B      45555
# C       6777
# D        445
# E      34452

# %%
pd.crosstab(df1.age,df1.name,rownames=['age'],colnames=['name'])
# Out:
# name  A  B  C  D  E
# age
# 4     0  1  0  0  0
# 23    1  0  0  0  0
# 24    0  0  0  1  0
# 25    0  0  0  0  1
# 52    0  0  1  0  0

# %%
pd.crosstab(df1.age , df1.name , rownames=['age'] , colnames=['name'] , values=df1.salary , aggfunc='mean')
# Out:
# name        A        B       C      D        E
# age
# 4         NaN  45555.0     NaN    NaN      NaN
# 23    23333.0      NaN     NaN    NaN      NaN
# 24        NaN      NaN     NaN  445.0      NaN
# 25        NaN      NaN     NaN    NaN  34452.0
# 52        NaN      NaN  6777.0    NaN      NaN

# %%
df.duplicated(keep=False)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 196    False
# 197    False
# 198    False
# 199    False
# 200    False
# Length: 201, dtype: bool

# %%
data={'name':['A','B','C','D','E','B','B'],'salary':[23333,45555,6777,445,34452,45555,45567],'gender':['F','M','M','F','M','M','M'],'age':[23,4,52,24,25,34,56]}
df1=pd.DataFrame(data)
df1
# Out:
#   name  salary gender  age
# 0    A   23333      F   23
# 1    B   45555      M    4
# 2    C    6777      M   52
# 3    D     445      F   24
# 4    E   34452      M   25
# 5    B   45555      M   34
# 6    B   45567      M   56

# %%
df1.duplicated(keep=False)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# dtype: bool

# %%
datas={'name':['A','B','C','D','E','B','B'],'salary':[23333,45555,6777,445,34452,45555,45555],'gender':['F','M','M','F','M','M','M'],'age':[23,4,52,24,25,4,4]}
df2=pd.DataFrame(datas)
df2
# Out:
#   name  salary gender  age
# 0    A   23333      F   23
# 1    B   45555      M    4
# 2    C    6777      M   52
# 3    D     445      F   24
# 4    E   34452      M   25
# 5    B   45555      M    4
# 6    B   45555      M    4

# %%
df2.duplicated(keep=False)
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# 5     True
# 6     True
# dtype: bool

# %%
df2=df2.loc[:,df2.columns!='gender']
df2
# Out:
#   name  salary  age
# 0    A   23333   23
# 1    B   45555    4
# 2    C    6777   52
# 3    D     445   24
# 4    E   34452   25
# 5    B   45555    4
# 6    B   45555    4

# %%
df2.duplicated(keep='first')            #excluding the first occurence
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6     True
# dtype: bool

# %%
df2.shape
# Out:
# (7, 3)

# %%
df3=df2.drop_duplicates()

# %%
df3.shape
# Out:
# (5, 3)

# %%
df1
# Out:
#   name  salary gender  age
# 0    A   23333      F   23
# 1    B   45555      M    4
# 2    C    6777      M   52
# 3    D     445      F   24
# 4    E   34452      M   25
# 5    B   45555      M   34
# 6    B   45567      M   56

# %%
df1.drop(index=range(1))
# Out:
#   name  salary gender  age
# 1    B   45555      M    4
# 2    C    6777      M   52
# 3    D     445      F   24
# 4    E   34452      M   25
# 5    B   45555      M   34
# 6    B   45567      M   56

# %%
df1.drop(index=range(1),inplace=True)

# %%
df1
# Out:
#   name  salary gender  age
# 1    B   45555      M    4
# 2    C    6777      M   52
# 3    D     445      F   24
# 4    E   34452      M   25
# 5    B   45555      M   34
# 6    B   45567      M   56

# %%
df1.drop('age',axis=1)       #droping a column
# Out:
#   name  salary gender
# 1    B   45555      M
# 2    C    6777      M
# 3    D     445      F
# 4    E   34452      M
# 5    B   45555      M
# 6    B   45567      M

# %%
df1=df1.replace(to_replace='B',value='F')

# %%
df1
# Out:
#   name  salary gender  age
# 1    F   45555      M    4
# 2    C    6777      M   52
# 3    D     445      F   24
# 4    E   34452      M   25
# 5    F   45555      M   34
# 6    F   45567      M   56

# %%
df1=df1.replace(to_replace=['F','C'],value=['G','K'])              #replacing multiple values

# %%
df1
# Out:
#   name  salary gender  age
# 1    G   45555      M    4
# 2    K    6777      M   52
# 3    D     445      G   24
# 4    E   34452      M   25
# 5    G   45555      M   34
# 6    G   45567      M   56

# %%
df1['gender']=df1['gender'].replace(to_replace=['M','F'],value=['Male','Female'])

# %%
df1
# Out:
#   name  salary gender  age
# 1    G   45555   Male    4
# 2    K    6777   Male   52
# 3    D     445      G   24
# 4    E   34452   Male   25
# 5    G   45555   Male   34
# 6    G   45567   Male   56

# %%
df1['gender']=df1['gender'].replace(to_replace=['G'],value=['Female'])
df1
# Out:
#   name  salary  gender  age
# 1    G   45555    Male    4
# 2    K    6777    Male   52
# 3    D     445  Female   24
# 4    E   34452    Male   25
# 5    G   45555    Male   34
# 6    G   45567    Male   56

# %%
df1.insert(4,'bmi',np.nan)             #inserting  A new column
df1
# Out:
#   name  salary  gender  age  bmi
# 1    G   45555    Male    4  NaN
# 2    K    6777    Male   52  NaN
# 3    D     445  Female   24  NaN
# 4    E   34452    Male   25  NaN
# 5    G   45555    Male   34  NaN
# 6    G   45567    Male   56  NaN

# %%
df1.insert(5,'bmilevel', value=[34,56,23,45,34,67])

# %%
df1
# Out:
#   name  salary  gender  age  bmi  bmilevel
# 1    G   45555    Male    4  NaN        34
# 2    K    6777    Male   52  NaN        56
# 3    D     445  Female   24  NaN        23
# 4    E   34452    Male   25  NaN        45
# 5    G   45555    Male   34  NaN        34
# 6    G   45567    Male   56  NaN        67

# %%
df1.loc[df1['bmilevel']>32,'bmi']='yes'
df1
# Out:
#   name  salary  gender  age  bmi  bmilevel
# 1    G   45555    Male    4  yes        34
# 2    K    6777    Male   52  yes        56
# 3    D     445  Female   24  NaN        23
# 4    E   34452    Male   25  yes        45
# 5    G   45555    Male   34  yes        34
# 6    G   45567    Male   56  yes        67

# %%
df1.loc[df1['bmilevel']<=32,'bmi']="no"
df1
# Out:
#   name  salary  gender  age  bmi  bmilevel
# 1    G   45555    Male    4  yes        34
# 2    K    6777    Male   52  yes        56
# 3    D     445  Female   24   no        23
# 4    E   34452    Male   25  yes        45
# 5    G   45555    Male   34  yes        34
# 6    G   45567    Male   56  yes        67

# %%
#groupby
gendergroup=df1.groupby(['gender'])
for gender,gendergp in gendergroup:
    print(gender)
    print(gendergroup.head(3))
# Out:
# Female
#   name  salary  gender  age  bmi  bmilevel
# 1    G   45555    Male    4  yes        34
# 2    K    6777    Male   52  yes        56
# 3    D     445  Female   24   no        23
# 4    E   34452    Male   25  yes        45
# Male
#   name  salary  gender  age  bmi  bmilevel
# 1    G   45555    Male    4  yes        34
# 2    K    6777    Male   52  yes        56
# 3    D     445  Female   24   no        23
# 4    E   34452    Male   25  yes        45

# %%
type(gendergroup)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
df2=df2.groupby([df2.get_group('gender')])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-132-3c225d18835a> in <module>
# ----> 1 df2=df2.groupby([df2.get_group('gender')])
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'get_group'

# %%
df3=df1.get_group('gender')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-136-b39a9d337589> in <module>
# ----> 1 df3=df1.get_group('gender')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'get_group'

# %%
gendergroup.min()
# Out:
#        name  salary  age  bmi  bmilevel
# gender
# Female    D     445   24   no        23
# Male      E    6777    4  yes        34

# %%
gendergroup.max()
# Out:
#        name  salary  age  bmi  bmilevel
# gender
# Female    D     445   24   no        23
# Male      K   45567   56  yes        67

# %%
gendergroup.mean()
# Out:
#          salary   age  bmilevel
# gender
# Female    445.0  24.0      23.0
# Male    35581.2  34.2      47.2

# %%
df1.groupby(by='name')['bmilevel'].sum()
# Out:
# name
# D     23
# E     45
# G    135
# K     56
# Name: bmilevel, dtype: int64

# %%
df1.groupby(by=['name','gender'])['salary'].count()
# Out:
# name  gender
# D     Female    1
# E     Male      1
# G     Male      3
# K     Male      1
# Name: salary, dtype: int64

# %%
df1.groupby(by='name').agg({'salary':[min,sum]})
# Out:
#      salary
#         min     sum
# name
# D       445     445
# E     34452   34452
# G     45555  136677
# K      6777    6777
